# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kenlm

# %matplotlib notebook

# %%
PATH_TRAIN_J = '../../../../data/raw/Oscar_data/PP/pp_train_adult_2634.json'
PATH_TRAIN_T = '../../../../data/raw/Oscar_data/PP/pp_train_adult_2634.txt'
PATH_VAL_J = '../../../../data/raw/Oscar_data/PP/pp_val_adult_829.json'
PATH_TEST_J = '../../../../data/raw/Oscar_data/PP/pp_test_adult_829.json'

PATH_MODEL_MINI = '../../../../models/English/PP_approach/kenlm_mini.binary'

# %%
def pp(log_score, length):
    return 10.0 ** (-log_score / length)

# %%
def get_pp (df):
    ls_pp = []
    for i, text in enumerate(df['text']):
        log_score = kenlm_mini.score(text, bos = True, eos = True)
        n = len(text.split())

        if n==0:
            ls_pp.append(0)
        else:
            ls_pp.append(pp(log_score, n))
    df['pp_score'] = ls_pp
    return (df)

# %%
def distributions_pp (df):
    print('---- 1 -----')
    display(df[df['annotation']==1].describe().transpose().round(2))
    print('\n---- 0 -----')
    display(df[df['annotation']==0].describe().transpose().round(2))


    sns.displot(df[['pp_score', 'annotation']], x="pp_score", hue="annotation", kind="kde", palette="PRGn")
    plt.show()
    
    plt.figure()
    sns.boxplot(x='annotation', y='pp_score', data=df[['annotation', 'pp_score']], palette="PRGn")
    plt.show()

# %%
df_val = pd.read_json(PATH_VAL_J)
df_val.reset_index(inplace=True, drop=True)
df_test = pd.read_json(PATH_TEST_J)
df_test.reset_index(inplace=True, drop=True)

# %%
kenlm_mini = kenlm.Model(PATH_MODEL_MINI)

# %%
df_val = get_pp (df_val)
display(df_val.head())
distributions_pp (df_val)
# Out:
#                                                 text  annotation  \
# 0  #ubuntu-qc 2011-09-05\n<qwebirc43563> BOnjours...           0
# 1  Anime is a phenomenon that has taken off like ...           1
# 2  Vasoconstrictive effects of human post-hemorrh...           0
# 3  Numerous infants born to women consuming foods...           0
# 4  A nonsurgical approach to low back pain.\nLow ...           0
#
#         pp_score
# 0  136306.340204
# 1    1024.710015
# 2    9790.022533
# 3    8104.352443
# 4    6850.865305
# ---- 1 -----
#             count     mean      std   min     25%      50%      75%       max
# annotation  329.0     1.00     0.00  1.00    1.00     1.00     1.00      1.00
# pp_score    329.0  1965.68  2031.81  1.47  862.51  1588.82  2604.13  18392.81
# ---- 0 -----
#             count      mean       std  min      25%      50%       75%  \
# annotation  500.0      0.00       0.0  0.0     0.00     0.00      0.00
# pp_score    500.0  47053.96  133169.4  0.0  2960.16  6041.88  15494.73
#
#                    max
# annotation        0.00
# pp_score    1071815.65
# <img src="data:image/png;base64,..." width="586">
# <img src="data:image/png;base64,..." width="640">

# %%
df_test = get_pp (df_test)
display(df_test.head())
distributions_pp (df_test)
# Out:
#                                                 text  annotation  \
# 0  1. Field of the Invention\nThe present inventi...           0
# 1  247CoupleCams.com – One place for the collecti...           1
# 2  Epidemia de gripe (debate) \nPresidente\nSegue...           0
# 3  The most random thing happened to me on Sunday...           1
# 4  Gustavo Cañete\n\nGustavo Cañete (born April 4...           0
#
#         pp_score
# 0    4607.550898
# 1       4.828216
# 2  223389.604669
# 3    1954.448474
# 4  171762.800343
# ---- 1 -----
#             count     mean      std   min    25%      50%      75%      max
# annotation  329.0     1.00     0.00  1.00    1.0     1.00     1.00      1.0
# pp_score    329.0  1738.33  2319.46  1.36  629.1  1314.29  2304.01  33576.6
# ---- 0 -----
#             count       mean       std  min      25%      50%       75%  \
# annotation  500.0       0.00       0.0  0.0     0.00     0.00      0.00
# pp_score    500.0  114947.77  834583.6  0.0  3161.08  6438.12  17113.67
#
#                     max
# annotation         0.00
# pp_score    17481780.34
# <img src="data:image/png;base64,..." width="586">
# <img src="data:image/png;base64,..." width="640">
